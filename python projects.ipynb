# %%
pwd
# Out:
# 'C:\\Users\\tanis\\anaconda_projects\\c801d546-2b24-4777-b8f9-b9ef8f5a8f32'

# %%
import random
number=random.randint(1,100)
print("Your system is going to generate a random number between 1-100 for you to guess. If you guess the number, you win. If you don't, you keep playing.")
count=0
while True:
    a=int(input("Guess a number between 1-100: "))
    count=count+1
    if a>number:
        print("The number you have guessed is higher.")
    elif a<number:
        print("The number you have guessed is lower. ")
    if a==number:
        break
print("CONGRATULATIONS! You have guessed the correct number in", count, "chances.")
# Out:
# Your system is going to generate a random number between 1-100 for you to guess. If you guess the number, you win. If you don't, you keep playing.
# Guess a number between 1-100:  59
# The number you have guessed is higher.
# Guess a number between 1-100:  52
# The number you have guessed is higher.
# Guess a number between 1-100:  41
# The number you have guessed is higher.
# Guess a number between 1-100:  35
# The number you have guessed is higher.
# Guess a number between 1-100:  15
# The number you have guessed is lower.
# Guess a number between 1-100:  25
# The number you have guessed is lower.
# Guess a number between 1-100:  29
# CONGRATULATIONS! You have guessed the correct number in 7 chances.

# %%
pwd
# Out:
# 'C:\\Users\\tanis\\OneDrive\\GitHub\\python-jupyter-projects'

# %%
print('hey')
# Out:
# hey
